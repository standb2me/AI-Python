# %%
print("2주차")
# Out:
# 2주차

# %%
print(10+20)
# Out:
# 30

# %%
import pandas as pd

# %%
print("2주차 코딩")
# Out:
# 2주차 코딩

# %%
print(1+2)
# Out:
# 3

# %%
a="2주차 코딩"
print(a)
# Out:
# 2주차 코딩

# %%
a=1
b=2
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 3
# -1
# 2
# 0.5

# %%
A=10
B=5
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A%B)
# Out:
# 15
# 5
# 50
# 2.0
# 0

# %%
A=12
B=7
print(A*B)
print(2*(A+B))
# Out:
# 84
# 38

# %%
A=88
B=92
C=75
print ((A+B+C)/3)
# Out:
# 85.0
